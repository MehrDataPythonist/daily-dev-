# %% [markdown]
# <a href="https://colab.research.google.com/github/MehrDataPythonist/daily-dev-/blob/main/Phi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# سلول 1: وارد کردن کتابخانه‌ها و تعریف پارامترها
import numpy as np
import matplotlib.pyplot as plt

mu = 0.1
beta_1 = -2.0573  # beta_i
beta_2 = 2.6724   # beta_r
gamma = -0.6814
delta = -0.0511
f_0 = 10

f_d_range = np.linspace(9.9, 10.1, 50)
phi_n_range = np.linspace(0, 0.5, 50)

# %%
# سلول 2: تعریف توابع مورد نیاز
def Psi_equation(r, Omega, phi_n):
    numerator = -((mu * gamma + Omega * delta) * r + (beta_1 * gamma + beta_2 * delta) * r**3)
    denominator = phi_n * (delta**2 + gamma**2)
    ratio = numerator / denominator
    ratio = np.clip(ratio, -1, 1)
    Psi_plus = np.arccos(ratio)
    Psi_minus = -np.arccos(ratio)
    return Psi_plus, Psi_minus

def jacobian_matrix(r, Psi, Omega, phi_n):
    j11 = mu + 3 * beta_1 * r**2
    j12 = phi_n * (-gamma * np.sin(Psi) + delta * np.cos(Psi))
    j21 = 2 * beta_2 * r + phi_n / r**2 * (gamma * np.sin(Psi) - delta * np.cos(Psi))
    j22 = -phi_n / r * (gamma * np.cos(Psi) + delta * np.sin(Psi))
    return np.array([[j11, j12], [j21, j22]])

# %%
# سلول 3: محاسبه ماتریس پایداری با استفاده از روش مقادیر ویژه
stability_matrix = np.zeros((len(f_d_range), len(phi_n_range)))

for i, f_d in enumerate(f_d_range):
    for j, phi_n in enumerate(phi_n_range):
        Omega = 2 * np.pi * (f_d - f_0)
        coefficients = [
            (beta_1**2 + beta_2**2),
            0,
            2 * (mu * beta_1 + Omega * beta_2),
            0,
            (mu**2 + Omega**2),
            0,
            -phi_n**2 * (gamma**2 + delta**2)  # توان دو فقط اینجا
        ]
        roots = np.roots(coefficients)
        real_roots = [r for r in roots if np.isreal(r)]
        positive_roots = [r.real for r in real_roots if r.real > 0]

        for r_star in positive_roots:
            Psi_plus, Psi_minus = Psi_equation(r_star, Omega, phi_n)
            for Psi_star in [Psi_plus, Psi_minus]:
                J_evaluated = jacobian_matrix(r_star, Psi_star, Omega, phi_n)
                eigenvalues = np.linalg.eigvals(J_evaluated)
                if all(e.real < 0 for e in eigenvalues):
                    stability_matrix[i, j] = 1
                    break
            if stability_matrix[i, j] == 1:
                break

# %%
# سلول 4: چاپ جزئیات برای روش مقادیر ویژه
for i, f_d in enumerate(f_d_range):
    for j, phi_n in enumerate(phi_n_range):
        Omega = 2 * np.pi * (f_d - f_0)
        coefficients = [
            (beta_1**2 + beta_2**2),
            0,
            2 * (mu * beta_1 + Omega * beta_2),
            0,
            (mu**2 + Omega**2),
            0,
            -phi_n**2 * (gamma**2 + delta**2)  # توان دو فقط اینجا
        ]
        roots = np.roots(coefficients)
        real_roots = [r for r in roots if np.isreal(r)]
        positive_roots = [r.real for r in real_roots if r.real > 0]

        print(f"f_d = {f_d:.4f}, phi_n = {phi_n:.4f}")
        print(f"All real roots: {[r.real for r in real_roots]}")
        print(f"Positive real roots: {positive_roots}")

        for r_star in positive_roots:
            Psi_plus, Psi_minus = Psi_equation(r_star, Omega, phi_n)
            for Psi_star in [Psi_plus, Psi_minus]:
                J_evaluated = jacobian_matrix(r_star, Psi_star, Omega, phi_n)
                eigenvalues = np.linalg.eigvals(J_evaluated)
                print(f"r* = {r_star:.4f}, Ψ* = {Psi_star:.4f}")
                print(f"Eigenvalues: {eigenvalues}")
                if all(e.real < 0 for e in eigenvalues):
                    print("Stable")
                else:
                    print("Unstable")
        print("\n")

        if i * len(phi_n_range) + j > 10:
            print("...")
            break
    if i * len(phi_n_range) + j > 10:
        break
# Out:
# f_d = 9.9000, phi_n = 0.0000
# All real roots: [0.0, 0.0]
# Positive real roots: []
#
#
# f_d = 9.9000, phi_n = 0.0102
# All real roots: [-0.010965420455277444, 0.010965420455277439]
# Positive real roots: [0.010965420455277439]
# r* = 0.0110, Ψ* = 1.4881
# Eigenvalues: [0.09950526+0.62767574j 0.09950526-0.62767574j]
# Unstable
# r* = 0.0110, Ψ* = -1.4881
# Eigenvalues: [0.05211559+0.63442303j 0.05211559-0.63442303j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0204
# All real roots: [-0.021967911605152518, 0.02196791160515252]
# Positive real roots: [0.02196791160515252]
# r* = 0.0220, Ψ* = 1.4890
# Eigenvalues: [0.09801434+0.62573707j 0.09801434-0.62573707j]
# Unstable
# r* = 0.0220, Ψ* = -1.4890
# Eigenvalues: [0.05070105+0.63438171j 0.05070105-0.63438171j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0306
# All real roots: [-0.03304575252243874, 0.03304575252243874]
# Positive real roots: [0.03304575252243874]
# r* = 0.0330, Ψ* = 1.4906
# Eigenvalues: [0.09550677+0.622471j 0.09550677-0.622471j]
# Unstable
# r* = 0.0330, Ψ* = -1.4906
# Eigenvalues: [0.04832195+0.63430652j 0.04832195-0.63430652j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0408
# All real roots: [-0.04423974987778899, 0.04423974987778899]
# Positive real roots: [0.04423974987778899]
# r* = 0.0442, Ψ* = 1.4928
# Eigenvalues: [0.09194709+0.61782267j 0.09194709-0.61782267j]
# Unstable
# r* = 0.0442, Ψ* = -1.4928
# Eigenvalues: [0.04494463+0.63418748j 0.04494463-0.63418748j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0510
# All real roots: [-0.055594799240517696, 0.0555947992405177]
# Positive real roots: [0.0555947992405177]
# r* = 0.0556, Ψ* = 1.4958
# Eigenvalues: [0.08728267+0.61171011j 0.08728267-0.61171011j]
# Unstable
# r* = 0.0556, Ψ* = -1.4958
# Eigenvalues: [0.04051918+0.63400965j 0.04051918-0.63400965j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0612
# All real roots: [-0.06716186691677165, 0.06716186691677169]
# Positive real roots: [0.06716186691677169]
# r* = 0.0672, Ψ* = 1.4995
# Eigenvalues: [0.08144021+0.60401811j 0.08144021-0.60401811j]
# Unstable
# r* = 0.0672, Ψ* = -1.4995
# Eigenvalues: [0.03497603+0.63375191j 0.03497603-0.63375191j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0714
# All real roots: [-0.07900066081057201, 0.07900066081057197]
# Positive real roots: [0.07900066081057197]
# r* = 0.0790, Ψ* = 1.5041
# Eigenvalues: [0.07432035+0.59458863j 0.07432035-0.59458863j]
# Unstable
# r* = 0.0790, Ψ* = -1.5041
# Eigenvalues: [0.02822093+0.63338514j 0.02822093-0.63338514j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0816
# All real roots: [-0.0911834258102061, 0.09118342581020614]
# Positive real roots: [0.09118342581020614]
# r* = 0.0912, Ψ* = 1.5097
# Eigenvalues: [0.0657895+0.58320591j 0.0657895-0.58320591j]
# Unstable
# r* = 0.0912, Ψ* = -1.5097
# Eigenvalues: [0.02012712+0.63286934j 0.02012712-0.63286934j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0918
# All real roots: [-0.10380061657509729, 0.10380061657509722]
# Positive real roots: [0.10380061657509722]
# r* = 0.1038, Ψ* = 1.5165
# Eigenvalues: [0.05566696+0.56957264j 0.05566696-0.56957264j]
# Unstable
# r* = 0.1038, Ψ* = -1.5165
# Eigenvalues: [0.01052318+0.63214905j 0.01052318-0.63214905j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.1020
# All real roots: [-0.11696983414501573, 0.1169698341450158]
# Positive real roots: [0.1169698341450158]
# r* = 0.1170, Ψ* = 1.5248
# Eigenvalues: [0.04370428+0.55327043j 0.04370428-0.55327043j]
# Unstable
# r* = 0.1170, Ψ* = -1.5248
# Eigenvalues: [-0.00082665+0.63114585j -0.00082665-0.63114585j]
# Stable
#
#
# f_d = 9.9000, phi_n = 0.1122
# All real roots: [-0.13085076685256453, 0.13085076685256458]
# Positive real roots: [0.13085076685256458]
# r* = 0.1309, Ψ* = 1.5349
# Eigenvalues: [0.02955013+0.5336904j 0.02955013-0.5336904j]
# Unstable
# r* = 0.1309, Ψ* = -1.5349
# Eigenvalues: [-0.01425566+0.62974518j -0.01425566-0.62974518j]
# Stable
#
#
# ...

# %%
# سلول 4: چاپ جزئیات برای روش مقادیر ویژه
for i, f_d in enumerate(f_d_range):
    for j, phi_n in enumerate(phi_n_range):
        Omega = 2 * np.pi * (f_d - f_0)
        coefficients = [
            (beta_1**2 + beta_2**2),
            0,
            2 * (mu * beta_1 + Omega * beta_2),
            0,
            (mu**2 + Omega**2),
            0,
            -phi_n**2 * (gamma**2 + delta**2)  # توان دو فقط اینجا
        ]
        roots = np.roots(coefficients)
        real_roots = [r for r in roots if np.isreal(r)]
        positive_roots = [r.real for r in real_roots if r.real > 0]

        print(f"f_d = {f_d:.4f}, phi_n = {phi_n:.4f}")
        print(f"All real roots: {[r.real for r in real_roots]}")
        print(f"Positive real roots: {positive_roots}")

        for r_star in positive_roots:
            Psi_plus, Psi_minus = Psi_equation(r_star, Omega, phi_n)
            for Psi_star in [Psi_plus, Psi_minus]:
                J_evaluated = jacobian_matrix(r_star, Psi_star, Omega, phi_n)
                eigenvalues = np.linalg.eigvals(J_evaluated)
                print(f"r* = {r_star:.4f}, Ψ* = {Psi_star:.4f}")
                print(f"Eigenvalues: {eigenvalues}")
                if all(e.real < 0 for e in eigenvalues):
                    print("Stable")
                else:
                    print("Unstable")
        print("\n")

        if i * len(phi_n_range) + j > 10:
            print("...")
            break
    if i * len(phi_n_range) + j > 10:
        break
# Out:
# f_d = 9.9000, phi_n = 0.0000
# All real roots: [0.0, 0.0]
# Positive real roots: []
#
#
# f_d = 9.9000, phi_n = 0.0102
# All real roots: [-0.010965420455277444, 0.010965420455277439]
# Positive real roots: [0.010965420455277439]
# r* = 0.0110, Ψ* = 1.4881
# Eigenvalues: [0.09950526+0.62767574j 0.09950526-0.62767574j]
# Unstable
# r* = 0.0110, Ψ* = -1.4881
# Eigenvalues: [0.05211559+0.63442303j 0.05211559-0.63442303j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0204
# All real roots: [-0.021967911605152518, 0.02196791160515252]
# Positive real roots: [0.02196791160515252]
# r* = 0.0220, Ψ* = 1.4890
# Eigenvalues: [0.09801434+0.62573707j 0.09801434-0.62573707j]
# Unstable
# r* = 0.0220, Ψ* = -1.4890
# Eigenvalues: [0.05070105+0.63438171j 0.05070105-0.63438171j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0306
# All real roots: [-0.03304575252243874, 0.03304575252243874]
# Positive real roots: [0.03304575252243874]
# r* = 0.0330, Ψ* = 1.4906
# Eigenvalues: [0.09550677+0.622471j 0.09550677-0.622471j]
# Unstable
# r* = 0.0330, Ψ* = -1.4906
# Eigenvalues: [0.04832195+0.63430652j 0.04832195-0.63430652j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0408
# All real roots: [-0.04423974987778899, 0.04423974987778899]
# Positive real roots: [0.04423974987778899]
# r* = 0.0442, Ψ* = 1.4928
# Eigenvalues: [0.09194709+0.61782267j 0.09194709-0.61782267j]
# Unstable
# r* = 0.0442, Ψ* = -1.4928
# Eigenvalues: [0.04494463+0.63418748j 0.04494463-0.63418748j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0510
# All real roots: [-0.055594799240517696, 0.0555947992405177]
# Positive real roots: [0.0555947992405177]
# r* = 0.0556, Ψ* = 1.4958
# Eigenvalues: [0.08728267+0.61171011j 0.08728267-0.61171011j]
# Unstable
# r* = 0.0556, Ψ* = -1.4958
# Eigenvalues: [0.04051918+0.63400965j 0.04051918-0.63400965j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0612
# All real roots: [-0.06716186691677165, 0.06716186691677169]
# Positive real roots: [0.06716186691677169]
# r* = 0.0672, Ψ* = 1.4995
# Eigenvalues: [0.08144021+0.60401811j 0.08144021-0.60401811j]
# Unstable
# r* = 0.0672, Ψ* = -1.4995
# Eigenvalues: [0.03497603+0.63375191j 0.03497603-0.63375191j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0714
# All real roots: [-0.07900066081057201, 0.07900066081057197]
# Positive real roots: [0.07900066081057197]
# r* = 0.0790, Ψ* = 1.5041
# Eigenvalues: [0.07432035+0.59458863j 0.07432035-0.59458863j]
# Unstable
# r* = 0.0790, Ψ* = -1.5041
# Eigenvalues: [0.02822093+0.63338514j 0.02822093-0.63338514j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0816
# All real roots: [-0.0911834258102061, 0.09118342581020614]
# Positive real roots: [0.09118342581020614]
# r* = 0.0912, Ψ* = 1.5097
# Eigenvalues: [0.0657895+0.58320591j 0.0657895-0.58320591j]
# Unstable
# r* = 0.0912, Ψ* = -1.5097
# Eigenvalues: [0.02012712+0.63286934j 0.02012712-0.63286934j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0918
# All real roots: [-0.10380061657509729, 0.10380061657509722]
# Positive real roots: [0.10380061657509722]
# r* = 0.1038, Ψ* = 1.5165
# Eigenvalues: [0.05566696+0.56957264j 0.05566696-0.56957264j]
# Unstable
# r* = 0.1038, Ψ* = -1.5165
# Eigenvalues: [0.01052318+0.63214905j 0.01052318-0.63214905j]
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.1020
# All real roots: [-0.11696983414501573, 0.1169698341450158]
# Positive real roots: [0.1169698341450158]
# r* = 0.1170, Ψ* = 1.5248
# Eigenvalues: [0.04370428+0.55327043j 0.04370428-0.55327043j]
# Unstable
# r* = 0.1170, Ψ* = -1.5248
# Eigenvalues: [-0.00082665+0.63114585j -0.00082665-0.63114585j]
# Stable
#
#
# f_d = 9.9000, phi_n = 0.1122
# All real roots: [-0.13085076685256453, 0.13085076685256458]
# Positive real roots: [0.13085076685256458]
# r* = 0.1309, Ψ* = 1.5349
# Eigenvalues: [0.02955013+0.5336904j 0.02955013-0.5336904j]
# Unstable
# r* = 0.1309, Ψ* = -1.5349
# Eigenvalues: [-0.01425566+0.62974518j -0.01425566-0.62974518j]
# Stable
#
#
# ...

# %%
# سلول 5: رسم نمودار کانتوری برای روش مقادیر ویژه
plt.figure(figsize=(12, 8))
f_d_grid, phi_n_grid = np.meshgrid(f_d_range, phi_n_range)
plt.contourf(f_d_grid, phi_n_grid, stability_matrix.T, levels=[0, 0.5, 1], colors=['white', 'orange'])
plt.xlabel('$f_d$')
plt.ylabel('$\phi_n$')
plt.title('Stability Region in $\phi_n$ vs $f_d$ Plane (Eigenvalue Method)')
plt.colorbar(ticks=[0, 1], label='Stability')
plt.grid(True)
plt.show()

# %%
# سلول 1: وارد کردن کتابخانه‌ها و تعریف پارامترها
import numpy as np
import matplotlib.pyplot as plt

mu = 0.1
beta_1 = -2.0573  # beta_i
beta_2 = 2.6724   # beta_r
gamma = -0.6814
delta = -0.0511
f_0 = 10

f_d_range = np.linspace(9.9, 10.1, 50)
phi_n_range = np.linspace(0, 0.5, 50)

# %%
# سلول 2: تعریف توابع مورد نیاز
def Psi_equation(r, Omega, phi_n):
    numerator = -((mu * gamma + Omega * delta) * r + (beta_1 * gamma + beta_2 * delta) * r**3)
    denominator = phi_n * (delta**2 + gamma**2)
    ratio = numerator / denominator
    ratio = np.clip(ratio, -1, 1)
    Psi_plus = np.arccos(ratio)
    Psi_minus = -np.arccos(ratio)
    return Psi_plus, Psi_minus

def jacobian_matrix(r, Psi, Omega, phi_n):
    j11 = mu + 3 * beta_1 * r**2
    j12 = phi_n * (-gamma * np.sin(Psi) + delta * np.cos(Psi))
    j21 = 2 * beta_2 * r + phi_n / r**2 * (gamma * np.sin(Psi) - delta * np.cos(Psi))
    j22 = -phi_n / r * (gamma * np.cos(Psi) + delta * np.sin(Psi))
    return np.array([[j11, j12], [j21, j22]])

# %%
# سلول 3: محاسبه ماتریس پایداری با استفاده از روش تریس و دترمینان
stability_matrix = np.zeros((len(f_d_range), len(phi_n_range)))

for i, f_d in enumerate(f_d_range):
    for j, phi_n in enumerate(phi_n_range):
        Omega = 2 * np.pi * (f_d - f_0)
        coefficients = [
            (beta_1**2 + beta_2**2),
            0,
            2 * (mu * beta_1 + Omega * beta_2),
            0,
            (mu**2 + Omega**2),
            0,
            -phi_n**2 * (gamma**2 + delta**2)  # توان دو فقط اینجا
        ]
        roots = np.roots(coefficients)
        real_roots = [r for r in roots if np.isreal(r)]
        positive_roots = [r.real for r in real_roots if r.real > 0]

        for r_star in positive_roots:
            Psi_plus, Psi_minus = Psi_equation(r_star, Omega, phi_n)
            for Psi_star in [Psi_plus, Psi_minus]:
                J_evaluated = jacobian_matrix(r_star, Psi_star, Omega, phi_n)
                det_J = np.linalg.det(J_evaluated)
                trace_J = np.trace(J_evaluated)
                if det_J > 0 and trace_J < 0:
                    stability_matrix[i, j] = 1
                    break
            if stability_matrix[i, j] == 1:
                break

# %%
# سلول 4: چاپ جزئیات برای روش تریس و دترمینان
for i, f_d in enumerate(f_d_range):
    for j, phi_n in enumerate(phi_n_range):
        Omega = 2 * np.pi * (f_d - f_0)
        coefficients = [
            (beta_1**2 + beta_2**2),
            0,
            2 * (mu * beta_1 + Omega * beta_2),
            0,
            (mu**2 + Omega**2),
            0,
            -phi_n**2 * (gamma**2 + delta**2)  # توان دو فقط اینجا
        ]
        roots = np.roots(coefficients)
        real_roots = [r for r in roots if np.isreal(r)]
        positive_roots = [r.real for r in real_roots if r.real > 0]

        print(f"f_d = {f_d:.4f}, phi_n = {phi_n:.4f}")
        print(f"All real roots: {[r.real for r in real_roots]}")
        print(f"Positive real roots: {positive_roots}")

        for r_star in positive_roots:
            Psi_plus, Psi_minus = Psi_equation(r_star, Omega, phi_n)
            for Psi_star in [Psi_plus, Psi_minus]:
                J_evaluated = jacobian_matrix(r_star, Psi_star, Omega, phi_n)
                det_J = np.linalg.det(J_evaluated)
                trace_J = np.trace(J_evaluated)
                print(f"r* = {r_star:.4f}, Ψ* = {Psi_star:.4f}")
                print(f"Determinant: {det_J:.4f}, Trace: {trace_J:.4f}")
                if det_J > 0 and trace_J < 0:
                    print("Stable")
                else:
                    print("Unstable")
        print("\n")

        if i * len(phi_n_range) + j > 10:
            print("...")
            break
    if i * len(phi_n_range) + j > 10:
        break
# Out:
# f_d = 9.9000, phi_n = 0.0000
# All real roots: [0.0, 0.0]
# Positive real roots: []
#
#
# f_d = 9.9000, phi_n = 0.0102
# All real roots: [-0.010965420455277444, 0.010965420455277439]
# Positive real roots: [0.010965420455277439]
# r* = 0.0110, Ψ* = 1.4881
# Determinant: 0.4039, Trace: 0.1990
# Unstable
# r* = 0.0110, Ψ* = -1.4881
# Determinant: 0.4052, Trace: 0.1042
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0204
# All real roots: [-0.021967911605152518, 0.02196791160515252]
# Positive real roots: [0.02196791160515252]
# r* = 0.0220, Ψ* = 1.4890
# Determinant: 0.4012, Trace: 0.1960
# Unstable
# r* = 0.0220, Ψ* = -1.4890
# Determinant: 0.4050, Trace: 0.1014
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0306
# All real roots: [-0.03304575252243874, 0.03304575252243874]
# Positive real roots: [0.03304575252243874]
# r* = 0.0330, Ψ* = 1.4906
# Determinant: 0.3966, Trace: 0.1910
# Unstable
# r* = 0.0330, Ψ* = -1.4906
# Determinant: 0.4047, Trace: 0.0966
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0408
# All real roots: [-0.04423974987778899, 0.04423974987778899]
# Positive real roots: [0.04423974987778899]
# r* = 0.0442, Ψ* = 1.4928
# Determinant: 0.3902, Trace: 0.1839
# Unstable
# r* = 0.0442, Ψ* = -1.4928
# Determinant: 0.4042, Trace: 0.0899
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0510
# All real roots: [-0.055594799240517696, 0.0555947992405177]
# Positive real roots: [0.0555947992405177]
# r* = 0.0556, Ψ* = 1.4958
# Determinant: 0.3818, Trace: 0.1746
# Unstable
# r* = 0.0556, Ψ* = -1.4958
# Determinant: 0.4036, Trace: 0.0810
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0612
# All real roots: [-0.06716186691677165, 0.06716186691677169]
# Positive real roots: [0.06716186691677169]
# r* = 0.0672, Ψ* = 1.4995
# Determinant: 0.3715, Trace: 0.1629
# Unstable
# r* = 0.0672, Ψ* = -1.4995
# Determinant: 0.4029, Trace: 0.0700
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0714
# All real roots: [-0.07900066081057201, 0.07900066081057197]
# Positive real roots: [0.07900066081057197]
# r* = 0.0790, Ψ* = 1.5041
# Determinant: 0.3591, Trace: 0.1486
# Unstable
# r* = 0.0790, Ψ* = -1.5041
# Determinant: 0.4020, Trace: 0.0564
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0816
# All real roots: [-0.0911834258102061, 0.09118342581020614]
# Positive real roots: [0.09118342581020614]
# r* = 0.0912, Ψ* = 1.5097
# Determinant: 0.3445, Trace: 0.1316
# Unstable
# r* = 0.0912, Ψ* = -1.5097
# Determinant: 0.4009, Trace: 0.0403
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.0918
# All real roots: [-0.10380061657509729, 0.10380061657509722]
# Positive real roots: [0.10380061657509722]
# r* = 0.1038, Ψ* = 1.5165
# Determinant: 0.3275, Trace: 0.1113
# Unstable
# r* = 0.1038, Ψ* = -1.5165
# Determinant: 0.3997, Trace: 0.0210
# Unstable
#
#
# f_d = 9.9000, phi_n = 0.1020
# All real roots: [-0.11696983414501573, 0.1169698341450158]
# Positive real roots: [0.1169698341450158]
# r* = 0.1170, Ψ* = 1.5248
# Determinant: 0.3080, Trace: 0.0874
# Unstable
# r* = 0.1170, Ψ* = -1.5248
# Determinant: 0.3983, Trace: -0.0017
# Stable
#
#
# f_d = 9.9000, phi_n = 0.1122
# All real roots: [-0.13085076685256453, 0.13085076685256458]
# Positive real roots: [0.13085076685256458]
# r* = 0.1309, Ψ* = 1.5349
# Determinant: 0.2857, Trace: 0.0591
# Unstable
# r* = 0.1309, Ψ* = -1.5349
# Determinant: 0.3968, Trace: -0.0285
# Stable
#
#
# ...

# %%
# سلول 5: رسم نمودار کانتوری برای روش تریس و دترمینان
plt.figure(figsize=(12, 8))
f_d_grid, phi_n_grid = np.meshgrid(f_d_range, phi_n_range)
plt.contourf(f_d_grid, phi_n_grid, stability_matrix.T, levels=[0, 0.5, 1], colors=['white', 'orange'])
plt.xlabel('$f_d$')
plt.ylabel('$\phi_n$')
plt.title('Stability Region in $\phi_n$ vs $f_d$ Plane (Trace-Determinant Method)')
plt.colorbar(ticks=[0, 1], label='Stability')
plt.grid(True)
plt.show()
